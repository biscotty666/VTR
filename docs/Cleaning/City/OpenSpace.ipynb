# %% [markdown]
# # Open Space

# %%
import geopandas as gpd

# %%
gpd.list_layers('data/openspace.zip')
# Out:
#         name geometry_type
# 0  openspace       Polygon

# %%
os = gpd.read_file('data/openspace.zip').to_crs(4267)
os.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    80 non-null     int64
#  1   Name        80 non-null     object
#  2   Address     65 non-null     object
#  3   Status      80 non-null     object
#  4   GISAcres    80 non-null     float64
#  5   SHAPE_Leng  80 non-null     float64
#  6   factyp_pre  22 non-null     object
#  7   factyp_und  39 non-null     object
#  8   factyp_fac  23 non-null     object
#  9   factyp_tra  11 non-null     object
#  10  factyp_spe  7 non-null      object
#  11  STAr        80 non-null     float64
#  12  STLe        80 non-null     float64
#  13  geometry    80 non-null     geometry
# dtypes: float64(4), geometry(1), int64(1), object(8)
# memory usage: 8.9+ KB

# %%
os.iloc[3]
# Out:
# OBJECTID                                                      4
# Name                          Southern Geologic Window (Closed)
# Address                                                    None
# Status                                         Closed To Public
# GISAcres                                             103.139037
# SHAPE_Leng                                           8997.35005
# factyp_pre                                                 None
# factyp_und                                                  yes
# factyp_fac                                                 None
# factyp_tra                                                 None
# factyp_spe                                                 None
# STAr                                              4492718.46899
# STLe                                                 8997.35005
# geometry      POLYGON ((-106.74475173703408 35.1537979788070...
# Name: 3, dtype: object

# %%
os = os[['OBJECTID', 'Name', 'Address', 'geometry']]

# %%
os.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OBJECTID  80 non-null     int64
#  1   Name      80 non-null     object
#  2   Address   65 non-null     object
#  3   geometry  80 non-null     geometry
# dtypes: geometry(1), int64(1), object(2)
# memory usage: 2.6+ KB

# %%
os.to_file('../../../data/local/abq_city_data.gpkg', layer='openspace')
os.to_file('../../../localData/City/openspace.gpkg')

# %%
import contextily as ctx

# %%
ax = os.plot(figsize=(10,8), alpha=0.7, column='Name')
ctx.add_basemap(ax, crs=os.crs, source=ctx.providers.Esri.NatGeoWorldMap);

# %%
os.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
